# %% [markdown]
# ### Урок 5. Проверка статистических гипотез. P-значения. Доверительные интервалы. A/B-тестирование

# %% [markdown]
# ####1. Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.

# %%
M = 80 
n = 256 
sigma = 16 
alfa = 0.95 
z = 1.96 
a = 80 - (z * sigma/256**0.5)
a1 = 80 + (z * sigma/256**0.5)
print(f'Доверительый интервал равен [{round(a,2)};{round(a1,2)}]')
# Out:
# Доверительый интервал равен [78.04;81.96]

# %% [markdown]
# ####2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1 Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95.

# %%
m = [6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1]
sr = sum(m) / len(m)
sd = 0
for i in m:
  sd += (i - sr)**2

d = sd / (len(m)-1)
sigma = d**0.5
z = 2.262
a = sr - z * sigma / 10**0.5
a1 = sr + z * sigma / 10**0.5
print(f'Доверительый интервал составляет от {round(a,2)} до {round(a1,2)}')
# Out:
# Доверительый интервал составляет от 6.27 до 6.91

# %% [markdown]
# ####3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметроказался равным 17.5 мм, а дисперсия известна и равна 4 кв.мм.

# %%
nu0 = 17 
nu1 = 17.5
alf = 0.05 
n = 100 
d = 4 
z0 = 1.645 # по таблице Z распределния для 0,05
z1 = (nu1 - nu0) / (d**0.5 / n**0.5)
print(f'Так как, критерий табличного({z0}) меньше, критерия расчитанного({z1}) мы приходим к выводу, что гипотеза Но не верная.')
# Out:
# Так как, критерий табличного(1.645) меньше, критерия расчитанного(2.5) мы приходим к выводу, что гипотеза Но не верная.

# %% [markdown]
# ####4. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %%
nu0 = 200 
m = [202, 203, 199, 197, 195, 201, 200, 204, 194, 190]
n = 10
nu1 = sum(m) / len(m)
alf = 0.01
t = 3.250 # по таблице t распределния для 0,005
sd = 0
for i in m:
  sd += (i - sr)**2

d = sd / (len(m)-1)
sigma = d**0.5

tr = (nu0 - nu1) / (sigma / n**0.5)
tr
print(f'Так как, расчетный критерий({round(tr,2)}) меньше критерия допустимого({t}) для доверительного интервала 99%, то мы приходим к выводу, что гипотеза Но верная.')
# Out:
# Так как, расчетный критерий(1.07) меньше критерия допустимого(3.25) для доверительного интервала 99%, то мы приходим к выводу, что гипотеза Но верная.
